# %%
import pandas as pd
import numpy as np
import tpqoa
from typing import List, Tuple
import matplotlib.pyplot as plt
from BollingerStrategy import get_data, bollinger_strategy, execute_trades, apply_returns, test_strategy
from Visualisation import plot_price_with_bands_and_signals, plot_cumulative_returns, plot_return_histogram, plot_zscore, plot_trade_context, plot_best_and_worst_trades

data = pd.read_csv("EUR_GBP_H1_2020_2024.csv", index_col=0, parse_dates=True)

tc = 0.7
leverage = 3
settings = [(50, 3, 1)]

test_strategy(data, settings, transaction_cost=tc, leverage=leverage, reversion=True, restrict_hours=True, plots=True)
# Out:
# Total return: 1.2914
#
# Number of trades: 2022
# 1.2914
